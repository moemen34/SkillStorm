# %% [markdown]
# # No Auth

# %%
import requests

url = 'https://api.imgflip.com/get_memes'
response = requests.get(url)

data = response.json()

memes = data['data']['memes']

memes_names = [meme["name"] for meme in memes]

memes_names
# Out:
# ['Drake Hotline Bling',
#  'Two Buttons',
#  'Distracted Boyfriend',
#  'Running Away Balloon',
#  'UNO Draw 25 Cards',
#  'Left Exit 12 Off Ramp',
#  'Bernie I Am Once Again Asking For Your Support',
#  'Waiting Skeleton',
#  "Gru's Plan",
#  'Change My Mind',
#  'Epic Handshake',
#  'Disaster Girl',
#  'Batman Slapping Robin',
#  'Sad Pablo Escobar',
#  'Always Has Been',
#  'Anakin Padme 4 Panel',
#  'Buff Doge vs. Cheems',
#  'X, X Everywhere',
#  'Woman Yelling At Cat',
#  'Tuxedo Winnie The Pooh',
#  'Trade Offer',
#  'Mocking Spongebob',
#  "I Bet He's Thinking About Other Women",
#  'Expanding Brain',
#  'Marked Safe From',
#  'Bike Fall',
#  'Monkey Puppet',
#  'Success Kid',
#  'One Does Not Simply',
#  "They're The Same Picture",
#  'Ancient Aliens',
#  'Boardroom Meeting Suggestion',
#  'Clown Applying Makeup',
#  'Hide the Pain Harold',
#  "Y'all Got Any More Of That",
#  'Megamind peeking',
#  "This Is Where I'd Put My Trophy If I Had One",
#  'This Is Fine',
#  'Mother Ignoring Kid Drowning In A Pool',
#  'Blank Nut Button',
#  'Bernie Sanders Once Again Asking',
#  'Is This A Pigeon',
#  'Oprah You Get A',
#  'where monkey',
#  'Flex Tape',
#  'Panik Kalm Panik',
#  'Inhaling Seagull',
#  'Laughing Leo',
#  'You Guys are Getting Paid',
#  '0 days without (Lenny, Simpsons)',
#  'Whisper and Goosebumps',
#  "They don't know",
#  'Who Killed Hannibal',
#  'A train hitting a school bus',
#  'Roll Safe Think About It',
#  'Evil Kermit',
#  'Sleeping Shaq',
#  'The Rock Driving',
#  'Grandma Finds The Internet',
#  'Squidward window',
#  'Types of Headaches meme',
#  'Surprised Pikachu',
#  'Leonardo Dicaprio Cheers',
#  'American Chopper Argument',
#  'Grant Gustin over grave',
#  'Pawn Stars Best I Can Do',
#  'All My Homies Hate',
#  'Soldier protecting sleeping child',
#  'Drake Blank',
#  'AJ Styles & Undertaker',
#  'Anime Girl Hiding from Terminator',
#  'Disappointed Black Guy',
#  "whe i'm in a competition and my opponent is",
#  'Finding Neverland',
#  'Futurama Fry',
#  'Megamind no bitches',
#  'The Scroll Of Truth',
#  'Star Wars Yoda',
#  'Bell Curve',
#  'Third World Skeptical Kid',
#  'Friendship ended',
#  'spiderman pointing at spiderman',
#  'Look At Me',
#  'Gus Fring we are not the same',
#  'Trump Bill Signing',
#  'is this butterfly',
#  'Domino Effect',
#  'Three-headed Dragon',
#  'Spongebob Ight Imma Head Out',
#  'The Most Interesting Man In The World',
#  'Unsettled Tom',
#  'Spider Man Triple',
#  'What Gives People Feelings of Power',
#  'Borat 2 Tonight Queen??',
#  'Bugs bunny communist',
#  'Scooby doo mask reveal',
#  "c'mon do something",
#  'Charlie Conspiracy (Always Sunny in Philidelphia)',
#  'say the line bart! simpsons',
#  'Two guys on a bus']

# %% [markdown]
# # with Key

# %%
import os
from dotenv import load_dotenv

load_dotenv()

base_url = 'https://www.alphavantage.co'
stocks_endpoint = '/query'

stocks_url = base_url+stocks_endpoint

api_key = os.environ['alphavantage_api_key']

params = {'function':'TIME_SERIES_INTRADAY', 
          'symbol': 'QQQ',
          'interval': '5min',
          'apikey' : api_key}



response2 = requests.get(stocks_url, params)

response2.json()
# Out:
# {'Meta Data': {'1. Information': 'Intraday (5min) open, high, low, close prices and volume',
#   '2. Symbol': 'QQQ',
#   '3. Last Refreshed': '2024-06-20 19:55:00',
#   '4. Interval': '5min',
#   '5. Output Size': 'Compact',
#   '6. Time Zone': 'US/Eastern'},
#  'Time Series (5min)': {'2024-06-20 19:55:00': {'1. open': '482.1400',
#    '2. high': '482.2600',
#    '3. low': '482.1200',
#    '4. close': '482.1950',
#    '5. volume': '6039'},
#   '2024-06-20 19:50:00': {'1. open': '482.0800',
#    '2. high': '482.1600',
#    '3. low': '482.0600',
#    '4. close': '482.0950',
#    '5. volume': '14771'},
#   '2024-06-20 19:45:00': {'1. open': '482.1200',
#    '2. high': '482.1200',
#    '3. low': '482.0300',
#    '4. close': '482.0700',
#    '5. volume': '4111'},
#   '2024-06-20 19:40:00': {'1. open': '482.2100',
#    '2. high': '482.2400',
#    '3. low': '482.0700',
#    '4. close': '482.1190',
#    '5. volume': '2550'},
#   '2024-06-20 19:35:00': {'1. open': '482.2250',
#    '2. high': '482.2600',
#    '3. low': '482.1900',
#    '4. close': '482.2000',
#    '5. volume': '1375'},
#   '2024-06-20 19:30:00': {'1. open': '482.2500',
#    '2. high': '482.3000',
#    '3. low': '482.1800',
#    '4. close': '482.2300',
#    '5. volume': '553'},
#   '2024-06-20 19:25:00': {'1. open': '482.3290',
#    '2. high': '482.3300',
#    '3. low': '482.2500',
#    '4. close': '482.2500',
#    '5. volume': '3577'},
#   '2024-06-20 19:20:00': {'1. open': '482.3000',
#    '2. high': '482.3300',
#    '3. low': '482.2500',
#    '4. close': '482.3200',
#    '5. volume': '3285'},
#   '2024-06-20 19:15:00': {'1. open': '482.1400',
#    '2. high': '482.3000',
#    '3. low': '482.1400',
#    '4. close': '482.3000',
#    '5. volume': '9617'},
#   '2024-06-20 19:10:00': {'1. open': '482.0000',
#    '2. high': '482.1700',
#    '3. low': '482.0000',
#    '4. close': '482.1600',
#    '5. volume': '4664'},
#   '2024-06-20 19:05:00': {'1. open': '482.1070',
#    '2. high': '482.1100',
#    '3. low': '482.0000',
#    '4. close': '482.0000',
#    '5. volume': '4750'},
#   '2024-06-20 19:00:00': {'1. open': '481.9600',
#    '2. high': '482.1000',
#    '3. low': '481.4700',
#    '4. close': '482.0600',
#    '5. volume': '16591'},
#   '2024-06-20 18:55:00': {'1. open': '481.9300',
#    '2. high': '482.0000',
#    '3. low': '481.4700',
#    '4. close': '481.9550',
#    '5. volume': '6513'},
#   '2024-06-20 18:50:00': {'1. open': '481.8500',
#    '2. high': '481.9500',
#    '3. low': '481.8400',
#    '4. close': '481.9250',
#    '5. volume': '6369'},
#   '2024-06-20 18:45:00': {'1. open': '481.8900',
#    '2. high': '481.8920',
#    '3. low': '481.8300',
#    '4. close': '481.8500',
#    '5. volume': '928'},
#   '2024-06-20 18:40:00': {'1. open': '481.8500',
#    '2. high': '481.9000',
#    '3. low': '481.8500',
#    '4. close': '481.8500',
#    '5. volume': '315'},
#   '2024-06-20 18:35:00': {'1. open': '481.8900',
#    '2. high': '481.9100',
#    '3. low': '481.8300',
#    '4. close': '481.8300',
#    '5. volume': '2221'},
#   '2024-06-20 18:30:00': {'1. open': '481.9100',
#    '2. high': '481.9600',
#    '3. low': '481.8800',
#    '4. close': '481.9200',
#    '5. volume': '5842'},
#   '2024-06-20 18:25:00': {'1. open': '481.9400',
#    '2. high': '481.9600',
#    '3. low': '481.8600',
#    '4. close': '481.9000',
#    '5. volume': '4138'},
#   '2024-06-20 18:20:00': {'1. open': '481.9800',
#    '2. high': '482.0150',
#    '3. low': '481.9300',
#    '4. close': '481.9450',
#    '5. volume': '1822'},
#   '2024-06-20 18:15:00': {'1. open': '481.9300',
#    '2. high': '482.0100',
#    '3. low': '481.9100',
#    '4. close': '481.9800',
#    '5. volume': '3131'},
#   '2024-06-20 18:10:00': {'1. open': '481.8600',
#    '2. high': '481.9500',
#    '3. low': '481.8600',
#    '4. close': '481.9490',
#    '5. volume': '18952'},
#   '2024-06-20 18:05:00': {'1. open': '481.7600',
#    '2. high': '481.8800',
#    '3. low': '481.7600',
#    '4. close': '481.8500',
#    '5. volume': '15918'},
#   '2024-06-20 18:00:00': {'1. open': '481.6300',
#    '2. high': '481.7900',
#    '3. low': '481.5020',
#    '4. close': '481.7700',
#    '5. volume': '49859'},
#   '2024-06-20 17:55:00': {'1. open': '481.6000',
#    '2. high': '481.6300',
#    '3. low': '481.5300',
#    '4. close': '481.6300',
#    '5. volume': '1594'},
#   '2024-06-20 17:50:00': {'1. open': '481.5500',
#    '2. high': '481.6100',
#    '3. low': '481.5400',
#    '4. close': '481.6000',
#    '5. volume': '2153'},
#   '2024-06-20 17:45:00': {'1. open': '481.5800',
#    '2. high': '481.5800',
#    '3. low': '481.5300',
#    '4. close': '481.5500',
#    '5. volume': '8667'},
#   '2024-06-20 17:40:00': {'1. open': '481.5500',
#    '2. high': '481.6900',
#    '3. low': '481.4800',
#    '4. close': '481.5780',
#    '5. volume': '17613'},
#   '2024-06-20 17:35:00': {'1. open': '481.5800',
#    '2. high': '481.6000',
#    '3. low': '481.4700',
#    '4. close': '481.5500',
#    '5. volume': '941512'},
#   '2024-06-20 17:30:00': {'1. open': '481.6000',
#    '2. high': '481.6700',
#    '3. low': '481.5600',
#    '4. close': '481.6000',
#    '5. volume': '6944'},
#   '2024-06-20 17:25:00': {'1. open': '481.5900',
#    '2. high': '481.6200',
#    '3. low': '481.5300',
#    '4. close': '481.5800',
#    '5. volume': '2949'},
#   '2024-06-20 17:20:00': {'1. open': '481.6300',
#    '2. high': '481.6300',
#    '3. low': '481.5000',
#    '4. close': '481.5900',
#    '5. volume': '8368'},
#   '2024-06-20 17:15:00': {'1. open': '481.6980',
#    '2. high': '481.7000',
#    '3. low': '481.6100',
#    '4. close': '481.6450',
#    '5. volume': '1697'},
#   '2024-06-20 17:10:00': {'1. open': '481.7500',
#    '2. high': '481.7500',
#    '3. low': '471.7990',
#    '4. close': '481.7000',
#    '5. volume': '60626'},
#   '2024-06-20 17:05:00': {'1. open': '481.7900',
#    '2. high': '481.7900',
#    '3. low': '481.6000',
#    '4. close': '481.7000',
#    '5. volume': '1194'},
#   '2024-06-20 17:00:00': {'1. open': '481.8100',
#    '2. high': '481.8300',
#    '3. low': '481.7100',
#    '4. close': '481.7750',
#    '5. volume': '1094'},
#   '2024-06-20 16:55:00': {'1. open': '481.7900',
#    '2. high': '481.8500',
#    '3. low': '481.7600',
#    '4. close': '481.7600',
#    '5. volume': '5575'},
#   '2024-06-20 16:50:00': {'1. open': '481.7200',
#    '2. high': '481.8000',
#    '3. low': '481.7200',
#    '4. close': '481.8000',
#    '5. volume': '3160'},
#   '2024-06-20 16:45:00': {'1. open': '481.7200',
#    '2. high': '481.7500',
#    '3. low': '481.6500',
#    '4. close': '481.7000',
#    '5. volume': '14385'},
#   '2024-06-20 16:40:00': {'1. open': '481.7000',
#    '2. high': '481.7600',
#    '3. low': '481.6600',
#    '4. close': '481.7050',
#    '5. volume': '11530'},
#   '2024-06-20 16:35:00': {'1. open': '481.7200',
#    '2. high': '481.7600',
#    '3. low': '481.6110',
#    '4. close': '481.6700',
#    '5. volume': '6474'},
#   '2024-06-20 16:30:00': {'1. open': '481.6300',
#    '2. high': '481.7300',
#    '3. low': '481.6300',
#    '4. close': '481.7250',
#    '5. volume': '11270'},
#   '2024-06-20 16:25:00': {'1. open': '481.5800',
#    '2. high': '481.6500',
#    '3. low': '481.5100',
#    '4. close': '481.6350',
#    '5. volume': '41353'},
#   '2024-06-20 16:20:00': {'1. open': '481.7000',
#    '2. high': '485.0950',
#    '3. low': '481.5700',
#    '4. close': '481.5900',
#    '5. volume': '304275'},
#   '2024-06-20 16:15:00': {'1. open': '481.3900',
#    '2. high': '481.7590',
#    '3. low': '481.3700',
#    '4. close': '481.6900',
#    '5. volume': '53494'},
#   '2024-06-20 16:10:00': {'1. open': '481.6700',
#    '2. high': '481.7100',
#    '3. low': '481.2860',
#    '4. close': '481.3800',
#    '5. volume': '271470'},
#   '2024-06-20 16:05:00': {'1. open': '481.4700',
#    '2. high': '481.7300',
#    '3. low': '481.4500',
#    '4. close': '481.6700',
#    '5. volume': '41429'},
#   '2024-06-20 16:00:00': {'1. open': '481.3700',
#    '2. high': '481.5500',
#    '3. low': '481.1800',
#    '4. close': '481.4300',
#    '5. volume': '1485479'},
#   '2024-06-20 15:55:00': {'1. open': '482.0900',
#    '2. high': '482.1000',
#    '3. low': '481.0400',
#    '4. close': '481.3800',
#    '5. volume': '2764756'},
#   '2024-06-20 15:50:00': {'1. open': '481.7900',
#    '2. high': '482.1900',
#    '3. low': '481.4800',
#    '4. close': '482.1100',
#    '5. volume': '853199'},
#   '2024-06-20 15:45:00': {'1. open': '481.7500',
#    '2. high': '482.1400',
#    '3. low': '481.6100',
#    '4. close': '481.7900',
#    '5. volume': '426898'},
#   '2024-06-20 15:40:00': {'1. open': '481.0300',
#    '2. high': '481.8250',
#    '3. low': '480.9800',
#    '4. close': '481.7600',
#    '5. volume': '594246'},
#   '2024-06-20 15:35:00': {'1. open': '481.8800',
#    '2. high': '481.9300',
#    '3. low': '480.9600',
#    '4. close': '481.0400',
#    '5. volume': '466057'},
#   '2024-06-20 15:30:00': {'1. open': '481.2900',
#    '2. high': '481.9110',
#    '3. low': '481.0650',
#    '4. close': '481.8800',
#    '5. volume': '422275'},
#   '2024-06-20 15:25:00': {'1. open': '479.9900',
#    '2. high': '481.3100',
#    '3. low': '479.9900',
#    '4. close': '481.2900',
#    '5. volume': '611291'},
#   '2024-06-20 15:20:00': {'1. open': '480.6000',
#    '2. high': '480.6800',
#    '3. low': '479.7000',
#    '4. close': '479.9890',
#    '5. volume': '570692'},
#   '2024-06-20 15:15:00': {'1. open': '481.1550',
#    '2. high': '481.1550',
#    '3. low': '480.4800',
#    '4. close': '480.5900',
#    '5. volume': '293737'},
#   '2024-06-20 15:10:00': {'1. open': '480.7200',
#    '2. high': '481.2600',
#    '3. low': '480.5800',
#    '4. close': '481.1600',
#    '5. volume': '650907'},
#   '2024-06-20 15:05:00': {'1. open': '480.3900',
#    '2. high': '480.9000',
#    '3. low': '480.2400',
#    '4. close': '480.7200',
#    '5. volume': '410159'},
#   '2024-06-20 15:00:00': {'1. open': '480.9300',
#    '2. high': '481.0800',
#    '3. low': '480.1300',
#    '4. close': '480.3800',
#    '5. volume': '352784'},
#   '2024-06-20 14:55:00': {'1. open': '481.2400',
#    '2. high': '481.5000',
#    '3. low': '480.8800',
#    '4. close': '480.9200',
#    '5. volume': '253213'},
#   '2024-06-20 14:50:00': {'1. open': '481.4500',
#    '2. high': '481.4800',
#    '3. low': '481.0200',
#    '4. close': '481.2200',
#    '5. volume': '224854'},
#   '2024-06-20 14:45:00': {'1. open': '481.4700',
#    '2. high': '481.7100',
#    '3. low': '481.3700',
#    '4. close': '481.4300',
#    '5. volume': '187967'},
#   '2024-06-20 14:40:00': {'1. open': '481.6000',
#    '2. high': '481.9200',
#    '3. low': '481.3340',
#    '4. close': '481.4800',
#    '5. volume': '189001'},
#   '2024-06-20 14:35:00': {'1. open': '481.9600',
#    '2. high': '481.9600',
#    '3. low': '481.2700',
#    '4. close': '481.5800',
#    '5. volume': '777323'},
#   '2024-06-20 14:30:00': {'1. open': '482.2700',
#    '2. high': '482.3800',
#    '3. low': '481.9600',
#    '4. close': '481.9800',
#    '5. volume': '299716'},
#   '2024-06-20 14:25:00': {'1. open': '482.1800',
#    '2. high': '482.4600',
#    '3. low': '481.8000',
#    '4. close': '482.2700',
#    '5. volume': '251973'},
#   '2024-06-20 14:20:00': {'1. open': '482.1100',
#    '2. high': '482.2300',
#    '3. low': '481.7700',
#    '4. close': '482.1710',
#    '5. volume': '220999'},
#   '2024-06-20 14:15:00': {'1. open': '481.9000',
#    '2. high': '482.2550',
#    '3. low': '481.8900',
#    '4. close': '482.1200',
#    '5. volume': '141667'},
#   '2024-06-20 14:10:00': {'1. open': '482.3380',
#    '2. high': '482.3900',
#    '3. low': '481.7550',
#    '4. close': '481.8600',
#    '5. volume': '284946'},
#   '2024-06-20 14:05:00': {'1. open': '482.1800',
#    '2. high': '482.5490',
#    '3. low': '482.1100',
#    '4. close': '482.3300',
#    '5. volume': '450972'},
#   '2024-06-20 14:00:00': {'1. open': '481.4300',
#    '2. high': '482.1800',
#    '3. low': '481.3300',
#    '4. close': '482.1800',
#    '5. volume': '338064'},
#   '2024-06-20 13:55:00': {'1. open': '480.8890',
#    '2. high': '481.4500',
#    '3. low': '480.8800',
#    '4. close': '481.4300',
#    '5. volume': '240081'},
#   '2024-06-20 13:50:00': {'1. open': '480.9000',
#    '2. high': '481.1800',
#    '3. low': '480.6100',
#    '4. close': '480.8900',
#    '5. volume': '216696'},
#   '2024-06-20 13:45:00': {'1. open': '481.0400',
#    '2. high': '481.1300',
#    '3. low': '480.6600',
#    '4. close': '480.9100',
#    '5. volume': '188682'},
#   '2024-06-20 13:40:00': {'1. open': '480.0100',
#    '2. high': '481.1200',
#    '3. low': '479.9600',
#    '4. close': '481.0650',
#    '5. volume': '387565'},
#   '2024-06-20 13:35:00': {'1. open': '480.1400',
#    '2. high': '480.3300',
#    '3. low': '479.6200',
#    '4. close': '480.0100',
#    '5. volume': '524508'},
#   '2024-06-20 13:30:00': {'1. open': '480.8200',
#    '2. high': '481.3400',
#    '3. low': '480.1000',
#    '4. close': '480.1800',
#    '5. volume': '315539'},
#   '2024-06-20 13:25:00': {'1. open': '481.0150',
#    '2. high': '481.1200',
#    '3. low': '480.6940',
#    '4. close': '480.8100',
#    '5. volume': '212649'},
#   '2024-06-20 13:20:00': {'1. open': '481.6500',
#    '2. high': '481.6900',
#    '3. low': '480.9300',
#    '4. close': '481.0250',
#    '5. volume': '202002'},
#   '2024-06-20 13:15:00': {'1. open': '481.4900',
#    '2. high': '481.9400',
#    '3. low': '481.4800',
#    '4. close': '481.6800',
#    '5. volume': '160192'},
#   '2024-06-20 13:10:00': {'1. open': '480.8000',
#    '2. high': '481.7600',
#    '3. low': '480.7600',
#    '4. close': '481.5000',
#    '5. volume': '294772'},
#   '2024-06-20 13:05:00': {'1. open': '481.2600',
#    '2. high': '481.5400',
#    '3. low': '480.5000',
#    '4. close': '480.8100',
#    '5. volume': '382158'},
#   '2024-06-20 13:00:00': {'1. open': '482.5100',
#    '2. high': '482.5100',
#    '3. low': '481.2300',
#    '4. close': '481.2500',
#    '5. volume': '366883'},
#   '2024-06-20 12:55:00': {'1. open': '482.4600',
#    '2. high': '482.6300',
#    '3. low': '482.0500',
#    '4. close': '482.5200',
#    '5. volume': '193004'},
#   '2024-06-20 12:50:00': {'1. open': '482.2800',
#    '2. high': '483.0000',
#    '3. low': '482.2800',
#    '4. close': '482.4800',
#    '5. volume': '433948'},
#   '2024-06-20 12:45:00': {'1. open': '482.0700',
#    '2. high': '482.5800',
#    '3. low': '482.0510',
#    '4. close': '482.2600',
#    '5. volume': '181180'},
#   '2024-06-20 12:40:00': {'1. open': '481.4700',
#    '2. high': '482.3200',
#    '3. low': '481.4700',
#    '4. close': '482.0900',
#    '5. volume': '401791'},
#   '2024-06-20 12:35:00': {'1. open': '481.2100',
#    '2. high': '481.7500',
#    '3. low': '480.9010',
#    '4. close': '481.4500',
#    '5. volume': '498436'},
#   '2024-06-20 12:30:00': {'1. open': '482.0750',
#    '2. high': '482.1400',
#    '3. low': '480.9060',
#    '4. close': '481.1900',
#    '5. volume': '636984'},
#   '2024-06-20 12:25:00': {'1. open': '482.7850',
#    '2. high': '483.4300',
#    '3. low': '482.0700',
#    '4. close': '482.1100',
#    '5. volume': '390294'},
#   '2024-06-20 12:20:00': {'1. open': '483.9300',
#    '2. high': '484.0100',
#    '3. low': '482.6710',
#    '4. close': '482.7900',
#    '5. volume': '534973'},
#   '2024-06-20 12:15:00': {'1. open': '484.4700',
#    '2. high': '484.5550',
#    '3. low': '483.9400',
#    '4. close': '483.9400',
#    '5. volume': '236803'},
#   '2024-06-20 12:10:00': {'1. open': '484.4450',
#    '2. high': '484.6600',
#    '3. low': '484.3300',
#    '4. close': '484.4700',
#    '5. volume': '109205'},
#   '2024-06-20 12:05:00': {'1. open': '484.4300',
#    '2. high': '484.8150',
#    '3. low': '484.4200',
#    '4. close': '484.4300',
#    '5. volume': '165352'},
#   '2024-06-20 12:00:00': {'1. open': '484.4700',
#    '2. high': '484.6400',
#    '3. low': '484.3000',
#    '4. close': '484.4100',
#    '5. volume': '250372'},
#   '2024-06-20 11:55:00': {'1. open': '484.7900',
#    '2. high': '484.8900',
#    '3. low': '484.4700',
#    '4. close': '484.4850',
#    '5. volume': '118839'},
#   '2024-06-20 11:50:00': {'1. open': '484.3700',
#    '2. high': '485.0100',
#    '3. low': '484.3100',
#    '4. close': '484.7720',
#    '5. volume': '359261'},
#   '2024-06-20 11:45:00': {'1. open': '485.4100',
#    '2. high': '485.4700',
#    '3. low': '484.3300',
#    '4. close': '484.3300',
#    '5. volume': '392876'},
#   '2024-06-20 11:40:00': {'1. open': '485.3100',
#    '2. high': '485.6250',
#    '3. low': '485.3100',
#    '4. close': '485.4100',
#    '5. volume': '137595'}}}

# %% [markdown]
# # OAuth
